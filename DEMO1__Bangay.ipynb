# %% [markdown]
# <a href="https://colab.research.google.com/github/Rhonan2/CPE-21A-CPE-1-1/blob/main/DEMO1__Bangay.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #PHYTHON PROGRAMMING LANGUAGE

# %% [markdown]
# ##RHONAN RICHMOND D. BANGAY
# ##BSCpE 1-1

# %%
x = 'Enjoying'
print('Programming is '+ x)
# Out:
# Programming is Enjoying

# %%
a = 'Pogi'
print(a + ' si Rhonan')
# Out:
# Pogi si Rhonan

# %%
x,y = 2,5
x<y and y==y
# Out:
# True

# %%
x,y = 5,2
x<y or y==x
# Out:
# False

# %%
b = float(4)
print(b)
# Out:
# 4.0

# %%
a,b,c = 0,1,2
print(a)
print(b)
print(c)
# Out:
# 0
# 1
# 2

# %%
a = 4
print(type(a))
# Out:
# <class 'int'>

# %%
a = 4.0
print(type(a))
# Out:
# <class 'float'>

# %%
B = int(4)
print(B)
# Out:
# 4
